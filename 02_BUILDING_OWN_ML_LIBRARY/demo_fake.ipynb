# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("gpa_iq.csv")

# %%
df.head()
# Out:
#    obs    gpa   iq  gender  concept
# 0    1  7.940  111       2       67
# 1    2  8.292  107       2       43
# 2    3  4.643  100       2       52
# 3    4  7.470  107       2       66
# 4    5  8.882  114       1       58

# %%
X=df.iloc[:,0:4]

# %%
X
# Out:
#     obs    gpa   iq  gender
# 0     1  7.940  111       2
# 1     2  8.292  107       2
# 2     3  4.643  100       2
# 3     4  7.470  107       2
# 4     5  8.882  114       1
# ..  ...    ...  ...     ...
# 73   85  9.000  112       1
# 74   86  9.500  112       1
# 75   87  6.057  114       2
# 76   88  6.057   93       1
# 77   89  6.938  106       2
#
# [78 rows x 4 columns]

# %%
y=df.iloc[:,-1]

# %%
y
# Out:
# 0     67
# 1     43
# 2     52
# 3     66
# 4     58
#       ..
# 73    60
# 74    70
# 75    51
# 76    21
# 77    56
# Name: concept, Length: 78, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2,test_size=0.2)

# %%
y_test
# Out:
# 28    65
# 65    73
# 27    53
# 13    64
# 75    51
# 71    42
# 25    70
# 45    52
# 59    66
# 23    68
# 14    56
# 41    70
# 1     43
# 66    59
# 21    20
# 53    54
# Name: concept, dtype: int64

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     obs     gpa   iq  gender
# 28   31   9.585  113       2
# 65   74   9.167  105       2
# 27   30   8.000  118       2
# 13   14   7.571  102       1
# 75   87   6.057  114       2
# 71   83   3.820   90       2
# 25   28  10.580  128       2
# 45   50   3.647   97       2
# 59   64   8.235  110       2
# 23   26   9.648  113       2
# 14   15   4.700   91       1
# 41   45   9.410  126       2
# 1     2   8.292  107       2
# 66   76   7.996  110       2
# 21   22   1.760  109       2
# 53   58   7.295   72       1

# %%
y_test
# Out:
# 28    65
# 65    73
# 27    53
# 13    64
# 75    51
# 71    42
# 25    70
# 45    52
# 59    66
# 23    68
# 14    56
# 41    70
# 1     43
# 66    59
# 21    20
# 53    54
# Name: concept, dtype: int64

# %%
lr.predict(X_test)
# Out:
# array([62.72313171, 57.17131979, 62.48968408, 54.54890089, 55.65589832,
#        44.62704545, 69.38475173, 48.55566946, 58.23984806, 63.06263376,
#        46.98419693, 66.30904434, 60.47597504, 57.31262917, 51.77507315,
#        41.45297783])

# %%
y_test.values
# Out:
# array([65, 73, 53, 64, 51, 42, 70, 52, 66, 68, 56, 70, 43, 59, 20, 54])

# %%
lr.predict()
