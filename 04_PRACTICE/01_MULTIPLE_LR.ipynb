# %%
import pandas as pd
import numpy as np

# %%
#concrete data set
# df=pd.read_csv(r"D:\16_MACHINE_LEARNING\02_MACHINE_LEARNING_USING_PYTHON\concrete_data.csv")
df=pd.read_csv(r"D:\fake\concrete_data_100k.csv")

df.head()
X=df.iloc[:,0:8]
y=df.iloc[:,-1]
print("Ddimension of Dataset",df.shape)
df.head()
# Out:
# Ddimension of Dataset (100000, 9)
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   314.0                 0.0    113.0  170.0              10.0
# 1   475.0               118.8      0.0  181.1               8.9
# 2   190.3                 0.0    125.2  166.6               9.9
# 3   246.8                 0.0    125.1  143.3              12.0
# 4   286.3               200.9      0.0  144.7              11.2
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0             925.0           783.0   28     38.46
# 1             852.1           781.5   28     68.30
# 2            1079.0           798.9  100     33.56
# 3            1086.8           800.9   14     42.22
# 4            1004.6           803.7    3     24.40

# %%
#sysnthetic datset
df=pd.read_csv(r"D:\fake\Multiple_Linear_Regression_Dataset.csv")
X=df.iloc[:,0:10]
y=df.iloc[:,-1]
print("Ddimension of Dataset",df.shape)
df.head()
# Out:
# Ddimension of Dataset (10000, 11)
#    Feature_1  Feature_2  Feature_3  Feature_4  Feature_5  Feature_6  \
# 0  37.454012  95.071431  73.199394  59.865848  15.601864  15.599452
# 1   2.058449  96.990985  83.244264  21.233911  18.182497  18.340451
# 2  61.185289  13.949386  29.214465  36.636184  45.606998  78.517596
# 3  60.754485  17.052412   6.505159  94.888554  96.563203  80.839735
# 4  12.203823  49.517691   3.438852  90.932040  25.877998  66.252228
#
#    Feature_7  Feature_8  Feature_9  Feature_10       Target
# 0   5.808361  86.617615  60.111501   70.807258  2849.367126
# 1  30.424224  52.475643  43.194502   29.122914  2069.657288
# 2  19.967378  51.423444  59.241457    4.645041  2152.194170
# 3  30.461377   9.767211  68.423303   44.015249  2787.136931
# 4  31.171108  52.006802  54.671028   18.485446  2337.586635

# %%
#student Performance Dataset
df=pd.read_csv(r"D:\fake\Student_Performance_1M.csv")
X=df.iloc[:,0:4]
y=df.iloc[:,-1]
print("Ddimension of Dataset",df.shape)
df.head()
# Out:
# Ddimension of Dataset (1000000, 5)
#    Hours Studied  Previous Scores  Sleep Hours  \
# 0              9               62            9
# 1              6               97            8
# 2              3               65            4
# 3              2               56            4
# 4              2               42            7
#
#    Sample Question Papers Practiced  Performance Index
# 0                                 6                 65
# 1                                 7                 92
# 2                                 9                 48
# 3                                 5                 28
# 4                                 8                 21

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,random_state=2,test_size=0.2)

# %% [markdown]
# # USING SCIKIT LEARN

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error
print("R2 SCORE :",r2_score(y_test,y_pred))
print("MEAN ABSOLUTE ERROR :",mean_absolute_error(y_test,y_pred))
print("MEAN SQUARED ERROR  :",mean_squared_error(y_test,y_pred))
print("ROOT MEAN SQUARED ERROR  :",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 SCORE : 0.6235643963057705
# MEAN ABSOLUTE ERROR : 8.239439993895898
# MEAN SQUARED ERROR  : 107.51804962656543
# ROOT MEAN SQUARED ERROR  : 10.369091070415257

# %%
lr.coef_
# Out:
# array([ 0.12077798,  0.1054747 ,  0.08960371, -0.14571446,  0.28704713,
#         0.01956395,  0.0213306 ,  0.11535533])

# %%
lr.intercept_
# Out:
# np.float64(-26.970956487907216)

# %%
lr.predict(X_test.loc[[788110]])  # Double brackets to keep it as a DataFrame

# %% [markdown]
# ## CUSTOM MULITPLE LR CLASS

# %%
class MeraLR:
    
    def __init__(self):
        self.coef_ = None
        self.intercept_ = None
        
    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1)
        
        # calcuate the coeffs
        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]
    
    def predict(self,X_test):
        y_pred = np.dot(X_test,self.coef_) + self.intercept_
        return y_pred

# %%
Clr=MeraLR()

# %%
Clr.fit(X_train,y_train)

# %%
y_pred=Clr.predict(X_test)

# %%
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_error,root_mean_squared_error
print("R2 SCORE :",r2_score(y_test,y_pred))
print("MEAN ABSOLUTE ERROR :",mean_absolute_error(y_test,y_pred))
print("MEAN SQUARED ERROR  :",mean_squared_error(y_test,y_pred))
print("ROOT MEAN SQUARED ERROR  :",root_mean_squared_error(y_test,y_pred))
# Out:
# R2 SCORE : 0.6235643963057086
# MEAN ABSOLUTE ERROR : 8.239439993900193
# MEAN SQUARED ERROR  : 107.51804962658312
# ROOT MEAN SQUARED ERROR  : 10.369091070416111

# %%
Clr.predict(X_test.loc[[788110]])  # Double brackets to keep it as a DataFrame

# %%
print("Intercept:", Clr.intercept_)  # Access the intercept
print("Coefficients:", Clr.coef_)
# Out:
# Intercept: -26.970956487999274
# Coefficients: [ 0.12077798  0.1054747   0.08960371 -0.14571446  0.28704713  0.01956395
#   0.0213306   0.11535533]
